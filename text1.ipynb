# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./1b_whole.xls","2563")

# %%
df
# Out:
#     ลำดับ      ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 0       1       ไม่ระบุ                   0                 0
# 1       2    ALFA ROMEO                   0                 0
# 2       3  ASTON MARTIN                   0                 0
# 3       4          AUDI                   0                 0
# 4       5        AUSTIN                   0                 0
# ..    ...           ...                 ...               ...
# 70     71           UTV                   0                 0
# 71     72    VOLKSWAGEN                   0                 0
# 72     73         VOLVO                   0                 0
# 73     74        WILLYS                   0                 0
# 74     75         อื่นๆ                   0                 1
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 0                    0                     0                    0
# 1                    0                     0                    0
# ...

# %%
#การเลือกช่วงข้อมูล colum
df[0:3]["ยี่ห้อรถ"]
# Out:
# 0         ไม่ระบุ
# 1      ALFA ROMEO
# 2    ASTON MARTIN
# Name: ยี่ห้อรถ, dtype: object

# %%
#การเลือกช่วงข้อมูล colum
df[["ไม่เกิน \n800 ซีซี","รถใช้เชื้อเพลิง ไฟฟ้า"]][:].sum()
# Out:
# ไม่เกิน \n800 ซีซี         64
# รถใช้เชื้อเพลิง ไฟฟ้า    1261
# dtype: int64

# %%
df[["ไม่เกิน \n800 ซีซี","รถใช้เชื้อเพลิง ไฟฟ้า"]][:].sum()
# Out:
# ไม่เกิน \n800 ซีซี         64
# รถใช้เชื้อเพลิง ไฟฟ้า    1261
# dtype: int64

# %%
df[["ยี่ห้อรถ","801 ถึง 900 ซีซี"]][1:10]
# Out:
#        ยี่ห้อรถ  801 ถึง 900 ซีซี
# 1    ALFA ROMEO                 0
# 2  ASTON MARTIN                 0
# 3          AUDI                 0
# 4        AUSTIN                 0
# 5          ALFA                 0
# 6       BENTLEY                 0
# 7          BENZ                 0
# 8           BMW                 0
# 9         BUICK                 0

# %%
df[1:10][["ยี่ห้อรถ","801 ถึง 900 ซีซี"]]
# Out:
#        ยี่ห้อรถ  801 ถึง 900 ซีซี
# 1    ALFA ROMEO                 0
# 2  ASTON MARTIN                 0
# 3          AUDI                 0
# 4        AUSTIN                 0
# 5          ALFA                 0
# 6       BENTLEY                 0
# 7          BENZ                 0
# 8           BMW                 0
# 9         BUICK                 0

# %%
df.loc["ALFA ROMEO":"BENTLEY"]["801 ถึง 900 ซีซี"]
#index_col="ยี่ห้อรถ"
# Out:
# Series([], Name: 801 ถึง 900 ซีซี, dtype: int64)

# %%
df["ยี่ห้อรถ"].str.match("ALFA ROMEO")
#match ต้องพิมให้ตรง
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 70    False
# 71    False
# 72    False
# 73    False
# 74    False
# Name: ยี่ห้อรถ, Length: 75, dtype: bool

# %%
df[df["ยี่ห้อรถ"].str.match("ALFA ROMEO")]
#ค้นหาต้องตรงกันทุกคำ
# Out:
#    ลำดับ    ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 1      2  ALFA ROMEO                   0                 0
#
#    901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 1                   0                     0                    0
#
#    1,201 ถึง 1,300 ซีซี  1,301 ถึง 1,400 ซีซี  1,401 ถึง 1,500 ซีซี  ...  \
# 1                     0                     0                     0  ...
#
#    2,301 ถึง 2,400 ซีซี  2,401 ถึง 2,500 ซีซี  2,501 ถึง 2,600 ซีซี  \
# 1                     0                     0                     0
#
#    2,601 ถึง 2,700 ซีซี  2,701 ถึง 2,800 ซีซี  2,801 ถึง 2,900 ซีซี  \
# 1                     0                     0                     0
#
#    2,901 ถึง 3,000 ซีซี  3,001 \nซีซีขึ้นไป  รถใช้เชื้อเพลิง ไฟฟ้า  รวม
# 1                     0                   0                      0    1
#
# [1 rows x 28 columns]

# %%
df[df["ยี่ห้อรถ"].str.contains("ALFA ROMEO")]
#ค้นหาไม่จำเป็นต้องตรงกันทุกคำ
# Out:
#    ลำดับ    ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 1      2  ALFA ROMEO                   0                 0
#
#    901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 1                   0                     0                    0
#
#    1,201 ถึง 1,300 ซีซี  1,301 ถึง 1,400 ซีซี  1,401 ถึง 1,500 ซีซี  ...  \
# 1                     0                     0                     0  ...
#
#    2,301 ถึง 2,400 ซีซี  2,401 ถึง 2,500 ซีซี  2,501 ถึง 2,600 ซีซี  \
# 1                     0                     0                     0
#
#    2,601 ถึง 2,700 ซีซี  2,701 ถึง 2,800 ซีซี  2,801 ถึง 2,900 ซีซี  \
# 1                     0                     0                     0
#
#    2,901 ถึง 3,000 ซีซี  3,001 \nซีซีขึ้นไป  รถใช้เชื้อเพลิง ไฟฟ้า  รวม
# 1                     0                   0                      0    1
#
# [1 rows x 28 columns]

# %%
#การใช้ Loop
for idx,row in df.iterrows():
    print("ยี่ห้อรถ : {} | {}".format(row["ยี่ห้อรถ"],row["รวม"]))
# Out:
# ยี่ห้อรถ : ไม่ระบุ | 0
# ยี่ห้อรถ : ALFA ROMEO | 1
# ยี่ห้อรถ : ASTON MARTIN | 14
# ยี่ห้อรถ : AUDI | 873
# ยี่ห้อรถ : AUSTIN | 0
# ยี่ห้อรถ : ALFA | 0
# ยี่ห้อรถ : BENTLEY | 84
# ยี่ห้อรถ : BENZ | 4
# ยี่ห้อรถ : BMW | 10655
# ยี่ห้อรถ : BUICK | 0
# ยี่ห้อรถ : CHEVROLET | 6472
# ยี่ห้อรถ : CHRYSLER | 0
# ยี่ห้อรถ : CITROEN | 0
# ยี่ห้อรถ : CHERY | 2
# ยี่ห้อรถ : DAEWOO | 0
# ยี่ห้อรถ : DAIHATSU | 0
# ยี่ห้อรถ : DAIMLER | 0
# ยี่ห้อรถ : DATSUN | 0
# ยี่ห้อรถ : DODGE | 0
# ยี่ห้อรถ : FERRARI | 69
# ยี่ห้อรถ : FIAT | 5
# ยี่ห้อรถ : FORD | 22934
# ยี่ห้อรถ : FOTON | 41
# ยี่ห้อรถ : HOLDEN | 0
# ยี่ห้อรถ : HONDA | 96063
# ยี่ห้อรถ : HYUNDAI | 146
# ยี่ห้อรถ : ISUZU | 72931
# ยี่ห้อรถ : JAGUAR | 38
# ยี่ห้อรถ : JEEP | 25
# ยี่ห้อรถ : KIA MASTER | 0
# ยี่ห้อรถ : KIA | 5
# ยี่ห้อรถ : LAMBORGHINI | 47
# ยี่ห้อรถ : LANCIA | 0
# ยี่ห้อรถ : LAND ROVER | 96
# ยี่ห้อรถ : LOTUS | 0
# ยี่ห้อรถ : LEXUS | 525
# ยี่ห้อรถ : MASERATI | 41
# ยี่ห้อรถ : MAZDA | 38389
# ยี่ห้อรถ : MG | 24428
# ...

# %%
#การเลือกแบบมีเงื่อนไข
df[df["รวม"]>=1000]
# Out:
#     ลำดับ       ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 8       9            BMW                   0                 0
# 10     11      CHEVROLET                   0                 0
# 21     22           FORD                   0                 0
# 24     25          HONDA                  38                 0
# 26     27          ISUZU                   0                 0
# 37     38          MAZDA                   0                 0
# 38     39             MG                   0                 0
# 39     40     MITSUBISHI                   0                 0
# 40     41           MINI                   0                 0
# 41     42  MERCEDES BENZ                   0                 0
# 45     46         NISSAN                   0                 0
# 51     52        PORSCHE                   0                 0
# 62     63         SUBARU                   0                 0
# 63     64         SUZUKI                  25                 0
# ...

# %%
#การเลือกแบบมีเงื่อนไข แบบมีหลายเงื่อนไข
df.loc[(df["รวม"]>=1000) & (df["รถใช้เชื้อเพลิง ไฟฟ้า"]>100)]
# Out:
#     ลำดับ ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  901 ถึง 1,000 ซีซี  \
# 38     39       MG                   0                 0                   0
#
#     1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  1,201 ถึง 1,300 ซีซี  \
# 38                     0                    0                     0
#
#     1,301 ถึง 1,400 ซีซี  1,401 ถึง 1,500 ซีซี  ...  2,301 ถึง 2,400 ซีซี  \
# 38                     0                 21244  ...                     0
#
#     2,401 ถึง 2,500 ซีซี  2,501 ถึง 2,600 ซีซี  2,601 ถึง 2,700 ซีซี  \
# 38                     3                     0                     0
#
#     2,701 ถึง 2,800 ซีซี  2,801 ถึง 2,900 ซีซี  2,901 ถึง 3,000 ซีซี  \
# 38                     0                     0                     0
#
#     3,001 \nซีซีขึ้นไป  รถใช้เชื้อเพลิง ไฟฟ้า    รวม
# 38                   0                    824  24428
#
# [1 rows x 28 columns]

# %%
df.loc[(df["ยี่ห้อรถ"].isin(["ALFA ROMEO","AUDI"]))]
# Out:
#    ลำดับ    ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 1      2  ALFA ROMEO                   0                 0
# 3      4        AUDI                   0                 0
#
#    901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 1                   0                     0                    0
# 3                   0                     0                    0
#
#    1,201 ถึง 1,300 ซีซี  1,301 ถึง 1,400 ซีซี  1,401 ถึง 1,500 ซีซี  ...  \
# 1                     0                     0                     0  ...
# 3                     0                    81                    34  ...
#
#    2,301 ถึง 2,400 ซีซี  2,401 ถึง 2,500 ซีซี  2,501 ถึง 2,600 ซีซี  \
# 1                     0                     0                     0
# 3                     0                     3                     0
#
#    2,601 ถึง 2,700 ซีซี  2,701 ถึง 2,800 ซีซี  2,801 ถึง 2,900 ซีซี  \
# 1                     0                     0                     0
# ...

# %%
#การเลียงลำดับข้อมูลตาม Index
df.sort_index()
# df.sort_index(ascending=False) #เลียงตรงกันข้าม
# Out:
#     ลำดับ      ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 0       1       ไม่ระบุ                   0                 0
# 1       2    ALFA ROMEO                   0                 0
# 2       3  ASTON MARTIN                   0                 0
# 3       4          AUDI                   0                 0
# 4       5        AUSTIN                   0                 0
# ..    ...           ...                 ...               ...
# 70     71           UTV                   0                 0
# 71     72    VOLKSWAGEN                   0                 0
# 72     73         VOLVO                   0                 0
# 73     74        WILLYS                   0                 0
# 74     75         อื่นๆ                   0                 1
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 0                    0                     0                    0
# 1                    0                     0                    0
# ...

# %%
#การเลียงลำดับข้อมูลตาม value
df.sort_values("รวม",ascending=False)
# Out:
#     ลำดับ    ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 66     67      TOYOTA                   0                 0
# 24     25       HONDA                  38                 0
# 26     27       ISUZU                   0                 0
# 39     40  MITSUBISHI                   0                 0
# 37     38       MAZDA                   0                 0
# ..    ...         ...                 ...               ...
# 11     12    CHRYSLER                   0                 0
# 46     47        NIVA                   0                 0
# 48     49  OLDSMOBILE                   0                 0
# 49     50        OPEL                   0                 0
# 0       1     ไม่ระบุ                   0                 0
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 66                   0                     0                46793
# 24               27524                     0                  183
# ...

# %%
#การเพิ่ม Colum
df["sum2"] = df["รวม"]
df
# Out:
#     ลำดับ      ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 0       1       ไม่ระบุ                   0                 0
# 1       2    ALFA ROMEO                   0                 0
# 2       3  ASTON MARTIN                   0                 0
# 3       4          AUDI                   0                 0
# 4       5        AUSTIN                   0                 0
# ..    ...           ...                 ...               ...
# 70     71           UTV                   0                 0
# 71     72    VOLKSWAGEN                   0                 0
# 72     73         VOLVO                   0                 0
# 73     74        WILLYS                   0                 0
# 74     75         อื่นๆ                   0                 1
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 0                    0                     0                    0
# 1                    0                     0                    0
# ...

# %%
#การเปลี่ยนชื่อ Colum
cols = {"sum2":"sum"}
df.rename(columns=cols,inplace=True)
df
# Out:
#     ลำดับ      ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 0       1       ไม่ระบุ                   0                 0
# 1       2    ALFA ROMEO                   0                 0
# 2       3  ASTON MARTIN                   0                 0
# 3       4          AUDI                   0                 0
# 4       5        AUSTIN                   0                 0
# ..    ...           ...                 ...               ...
# 70     71           UTV                   0                 0
# 71     72    VOLKSWAGEN                   0                 0
# 72     73         VOLVO                   0                 0
# 73     74        WILLYS                   0                 0
# 74     75         อื่นๆ                   0                 1
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 0                    0                     0                    0
# 1                    0                     0                    0
# ...

# %%
#การลบ Colum
new1 = df.drop("sum",axis=1)
new1
# Out:
#     ลำดับ      ยี่ห้อรถ  ไม่เกิน \n800 ซีซี  801 ถึง 900 ซีซี  \
# 0       1       ไม่ระบุ                   0                 0
# 1       2    ALFA ROMEO                   0                 0
# 2       3  ASTON MARTIN                   0                 0
# 3       4          AUDI                   0                 0
# 4       5        AUSTIN                   0                 0
# ..    ...           ...                 ...               ...
# 70     71           UTV                   0                 0
# 71     72    VOLKSWAGEN                   0                 0
# 72     73         VOLVO                   0                 0
# 73     74        WILLYS                   0                 0
# 74     75         อื่นๆ                   0                 1
#
#     901 ถึง 1,000 ซีซี  1,001 ถึง 1,100 ซีซี  1,101 ถึง 1200 ซีซี  \
# 0                    0                     0                    0
# 1                    0                     0                    0
# ...
